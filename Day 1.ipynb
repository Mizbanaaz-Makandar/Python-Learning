# %% [markdown]
# ## *Python Introduction :*
#
# Python is interpreated, dynamically typed and high level programming language.
#
# * Python is easy to understand and learn.
# * Interpreated lang mns (line by line code will gets executed)
# * dynamically typed (we dont have to pass on datatypes at the start of python code.
# * Python is open source(Can be installed on any operating system).
# * Python is free source(need not have to pay for its installation purpose).
#
# ## Application of Python:
#
# 1. Web devlopment
# 2. Game deplopment
# 3. Software devlopment
# 4. Data science
# 5. Machine learning
# 6. AI
#
# # Datatypes of Python:
# * Single value datatype:
#  1. integer(int) : Whole numbers e.g. 100,200 etc
#  2. float: Numbers with decimal e.g. 50.55, 22.53 etc
#  3. boolean : True/False
#
# * Sequential Datatype:
# 1. String (You Can store charachters text or date or numbers)
# 2. List
# 3. Tuple
# 4. Set
# 5. Dictionary
#
# # Variable :
# Fixed memory location.
#
# * Rules of writting variable:
# 1. Variable should not start with number values.
# 2. If you want to create two words as variable name pass underscores inbetween those words e.g. machine_learning
# 3. Python is case sensitive.

# %%
# for commenting purpose in code cell
a = 10
a
# Out:
# 10

# %%
1_one = 100
print(1_one)
# Out:
#   Cell In[4], line 1
#     1_one = 100
#      ^
# SyntaxError: invalid decimal literal

# %%
one_1 = 100
one_1
# Out:
# 100

# %%
Var = 20.55
print(Var)
# Out:
# 20.55

# %%
VAR_1 = "Hello, Welcome to Python Course"
VAR_1
# Out:
# 'Hello, Welcome to Python Course'

# %%
machine_learning = "Branch of AI"
machine_learning
# Out:
# 'Branch of AI'

# %%
100
# Out:
# 100

# %%
50.56
# Out:
# 50.56

# %%
100 + 50
# Out:
# 150

# %%
a = 100 
b = 100
c = a + b
print(c)
# Out:
# 200

# %%
# Arthematic Operator : 
# adiition
10 + 20
# Out:
# 30

# %%
# Subtraction : 

10 - 5
# Out:
# 5

# %%
# Multiplication: 
5 * 2
# Out:
# 10

# %%
# Division : It will always return o/p in float datatype

10 / 2
# Out:
# 5.0

# %%
# Floor division : It will always return o/p in int datatype

10 // 2
# Out:
# 5

# %%
# Modulus : It will return o/p as remainder

10 % 3
# Out:
# 1

# %%
# Complex number: Imaginary number

a = 2 + 3j
print(type(a))
# Out:
# <class 'complex'>

# %%
x = 100.55
print(type(x))
# Out:
# <class 'float'>

# %%
# Python program to take values from user side
x = int(input("Enter any value for x : "))
y = int(input("Enter any value for y: "))

z = x + y
print(z)
# Out:
# Enter any value for x :  400
# Enter any value for y:  500
# 900

# %%
a = float(input("Any value of a: "))
b = float(input("Any value of b: "))

c = a * b
print(c)
# Out:
# Any value of a:  5.2
# Any value of b:  1.25
# 6.5

# %%
p = eval(input("Value for p: "))
q = eval(input("Value for q: "))

r = p-q
print(r)
# Out:
# Value for p:  50.55
# Value for q:  20
# 30.549999999999997

# %%
Name = input("Enter name: ")
print(Name)
# Out:
# Enter name:  Priya
# Priya

# %%
# Python Program to find Area of reactangle: 

length = eval(input("Enter len of rect: "))
width = eval(input("Enter width of rectangle: "))

Area = length*width
print(Area)
# Out:
# Enter len of rect:  78
# Enter width of rectangle:  5.2
# 405.6

# %%
# Exponential operator : **

10 ** 3
# Out:
# 1000

# %%
2 ** 3
# Out:
# 8
